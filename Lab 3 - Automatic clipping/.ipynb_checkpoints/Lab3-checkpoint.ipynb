# %% [markdown]
# ## Lab #3

# %% [markdown]
# ## Transcribe video recordings audio

# %%
import boto3
import time
import urllib.request
import json
import pandas as pd
import datetime as dt
import re

region = boto3.Session().region_name
#media = 's3://rodzanto2020ml/sports/football2_in/Football2.mp4'
media = 's3://rodzanto2020ml/sports/football1/full-match-real-madrid-vs-atletico-de-madrid-laliga-20172018.mp4'
#job_name = 'football2-transcription'
job_name = 'football1-transcription'

print('region: {}'.format(region))
print('media: {}'.format(media))
print('transcribe-job: {}'.format(job_name))
# Out:
# region: eu-west-1
# media: s3://rodzanto2020ml/sports/football1/full-match-real-madrid-vs-atletico-de-madrid-laliga-20172018.mp4
# transcribe-job: football1-transcription

# %%
transcribe = boto3.client('transcribe', region_name=region)

# %%
transcribe.start_transcription_job(TranscriptionJobName=job_name, Media={'MediaFileUri': media}, MediaFormat='mp4', LanguageCode='es-ES')

# %%
while True:
    status = transcribe.get_transcription_job(TranscriptionJobName=job_name)
    if status['TranscriptionJob']['TranscriptionJobStatus'] in ['COMPLETED', 'FAILED']:
        break
    print("Not ready yet...")
    time.sleep(2)
print(status)
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'football1-transcription', 'TranscriptionJobStatus': 'COMPLETED', 'LanguageCode': 'es-ES', 'MediaSampleRateHertz': 44100, 'MediaFormat': 'mp4', 'Media': {'MediaFileUri': 's3://rodzanto2020ml/sports/football1/full-match-real-madrid-vs-atletico-de-madrid-laliga-20172018.mp4'}, 'Transcript': {'TranscriptFileUri': 'https://s3.eu-west-1.amazonaws.com/aws-transcribe-eu-west-1-prod/889960878219/football1-transcription/6988109e-f224-45a2-8130-bb408232b747/asrOutput.json?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEAYaCWV1LXdlc3QtMSJHMEUCIQD6px3QrfxxAjgtof%2F42Pi98xwKRmfDeneMZlEA%2BVjtxAIgeBRyDge0QPbxj58oEgjd4r9xCjhqHTiSl5QHXeNbHx8qvQMI7%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARACGgw1ODcwMTc2NjM0MTciDKNmIz%2FhiZj6sQFE2SqRAwEM8JxELoa17GnGHfEeHbJahVwR0LhHOL8H0lIJC9%2F1rGt%2B2tbUgF%2Bi5I4N2jyvBeFwQ3yj%2BvGl6DXLHNl6TFKfthy0qlzi6TFM3i6bKTzVNAwZj32He4sjPxTcXadRfe4kxBzYQVG%2Fwe8Hk8zlTLh8jDDK9Uj%2FKXNoure6qYXj0koylvDSKjONGvjLr6ijZ0wbTfY0EFLTGxwAttn%2FLUSyvHEUGHFdysp6T8RvTtnAQ%2FC5eS6IG0NMQL4XoOL6HdAqC1kHM1ckopOxvxRGgOEpzxZiK05FyGqKCqfI16IdktH8Khbcfund2ugM4xdiCLitsm2Fo45QobaEERbypyyuIMC7RH9ii3HI6nAez0AGdkpMAfpsmgv2h%2BG4N475YK6oJD9HfOuczRGhQIRtgDwmHhIlevB3VzQ2nGfq94s2LTDp2GFAju28wSGKg%2BE9Cd9dKLGNrLzLALa0B%2FFMxj%2FJyPwi6FNvq5r%2BQ9ARkHn7GkP%2FUOlS8JPMyvjYnehxpI0nyZVb1xrGzQA3B4RW89ZtMMvX6oAGOusBIRM%2B0wzq1ORQZTBipPLYRSlIoieO6DYmHoVFoeSRbb9SE9WZpDp%2FZ2WBepR3Utok1T45B5RM5rZ6GdWAwjEgOQW5uMWn3Tjh0H2TVrLSMD8jGksr5uY0C31AKLBM1D4w1XYUNKGCp%2F%2BJed4Us%2BDcAzZk9BHnY5f96BamUzHjbxP3zJ5WW9XskIAXNzhotNKMnQ8diMGbqXusH3s%2FJE24D%2B%2FG4SBdR2GM97SeRDJKhZ170xtwjpdUy4Oio0fD37zK2T6MlUMf7ZUTuQotkP8psJH7wHdqIToShhd3m7dkoitBVdCvN27lIbrjOw%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210203T145034Z&X-Amz-SignedHeaders=host&X-Amz-Expires=900&X-Amz-Credential=ASIAYRLH2WO4WE4ZLYQK%2F20210203%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Signature=8d430e3a3c79f91515993dab29a61252c2f1cec9b566b1c1f2da503a0627d6e2'}, 'StartTime': datetime.datetime(2021, 2, 3, 12, 44, 31, 326000, tzinfo=tzlocal()), 'CreationTime': datetime.datetime(2021, 2, 3, 12, 44, 31, 301000, tzinfo=tzlocal()), 'CompletionTime': datetime.datetime(2021, 2, 3, 12, 54, 27, 527000, tzinfo=tzlocal()), 'Settings': {'ChannelIdentification': False, 'ShowAlternatives': False}}, 'ResponseMetadata': {'RequestId': '97a875f1-4af7-42df-afd4-33232f62cfe1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1', 'date': 'Wed, 03 Feb 2021 14:50:34 GMT', 'x-amzn-requestid': '97a875f1-4af7-42df-afd4-33232f62cfe1', 'content-length': '2083', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %%
if status['TranscriptionJob']['TranscriptionJobStatus'] == 'COMPLETED':
    response = urllib.request.urlopen(status['TranscriptionJob']['Transcript']['TranscriptFileUri'])
    data = json.loads(response.read())
    text = data['results']['transcripts'][0]['transcript']
    search_words = ["gol", "tarjeta", "falta", "disparo", "amarilla", "roja"]
    for i, s in enumerate(search_words):
        if (search_words[i] in text):
            text = re.sub(r'\b'+search_words[i]+r'\b', '\033[44;33m{}\033[m'.format(search_words[i]), text)
    print(text)
# Out:
# Qué tal amigos? Sólo dos Bienvenidos a Madrid. Bienvenidos al estadio Santiago Bernabéu. Bienvenidos a la Liga Santander en bien la Liga. Lo que hoy nos ocupa no es un partido más. No es un partido cualquiera. Es el derbi de la capital. Real Madrid Atlético de Madrid, tercero contra segundo clasificado. Con la prevalencia, la supremacía del fútbol capitalino en juego en noventa minutos de puro fútbol que compartimos desde ya con Rubén, Uría, Jorge, Valdano ya, excepto reciben ellos todos. Buenas tardes. Hola, qué tal? Efectivamente, partido de estos tan marcado en el calendario partido entre dos equipos que no solamente se juegan cosas de la tabla de clasificación, sino que se juega buena parte de su honor contra Jackie. Felicita muchísima historia. Así que una gran tarde de fútbol l- Si, evidentemente también en estado de ánimo para para reforzarlo o para matizar lo no. Los dos equipos probablemente tienen ahora mismo el gran objetivo en en Europa. Pero acabar por encima del vecino del rival es algo que está también entre esas prioridades, no? Pero importante, Importante salir de aquí, reforzada metal, vete con una buena actuación, pero puede resultar Bueno y al final es un nuevo capítulo más de una historia de desamor que lleva muchos años, no. Al final son dos viejos conocidos, Los, Enemigos íntimos que chocan entre sí por un puesto de honor el en la Liga, no. Al final, tanto al Madrid como al Atlético, a todos los seguidores les han enseñado lo mismo desde pequeñitos es mucho mejor ser segundos de ser tercero Imagen imperial majestuosa del estadio Santiago Bernabéu al que están a punto de saltar, al que saltan ya de hecho, los integrantes de ambos equipos. Con el equipo arbitral, con el cuarteto arbitral a la cabeza y como siempre, muy cerquita del aquí o muy cerca de los jugadores a pie de césped, complementado la transmisión esta Ricardo Ros etiquetan Ricardo Cómo estás? Hola José muy buenas Jorge acceden Rubén Muy buenas tardes a todos. Es el Santiago Bernabéu que poco a poco se va llenando para el partido que va a comenzar a partir de las cuatro y cuarto de la tarde. Dijo enorme el que se despliega todo el Foto Sur con el escudo del Real Madrid con la Copa de la Liga, con la Copa de la Champions y con los protagonistas ya sobre el terreno de juego. Los blancos del Real Madrid, los rojiblancos del Atlético aparecieron a los futbolistas de ambos conjuntos. Arranca el pasamanos protocolario. Nos fijamos bien los Hortes, empezando por el Real Madrid que viene de ganar pero a tres en Turín y que teniendo en cuenta todas las competiciones, ha ganado once de los últimos doce compromisos. En un momento tremendamente dulce, tremendamente inspirado, que encara al equipo. Define entidad este término en la capital con los siguientes once futbolistas que dolor Navas para estar en la portería, Defensa para Dani, Carvajal para Sergio, Ramos y Marcelo en el templo del campo Lucas Vázquez Kowalczyk, Toni Kroos y marcó Asencio arriba carretera y Cristiano Ronaldo. Siempre que no juega Casimiro uno tiene una cierta sensación de vacío, pero la ausencia queda compensada por jugadores de la calidad de Asencio o de Lucas Vásquez que le van a dar mucha frescura al juego ofensivo de suplentes. Hoy en el equipo de Ciudad Ricardo Kiko Casilla como portero suplente. Benzema Modric Casimiro Theo Hernández Marcos Llorente Isco Esa es la selección de Filadelfia para el partido de hoy vamos con el once del Atlético de Madrid, que también viene de ganar en Europa se impuso dos a cero a Sporting de Portugal en la ida de los cuartos de final de la Europa League y ha ganado trece de los últimos quince partidos teniendo en cuenta todas las competiciones. Así que el comentario positivo En cuanto a la dinámica reciente que hacíamos para el Real Madrid es perfectamente aplicable a los chicos de Diego Pablo Simeone que el día de hoy forman con el siguiente once ya no habla, que está bajo palos con Juanfran, Xabi, Godín y Lucas en defensa dentro del campo con  ...

# %% [markdown]
# #### Mark keywords in transcriptions

# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.collections import PolyCollection
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

def format_func(x, pos):
    hours = int(x//3600)
    minutes = int((x%3600)//60)
    seconds = int(x%60)
    return "{:d}:{:02d}:{:02d}".format(hours, minutes, seconds)
formatter = FuncFormatter(format_func)

def plot_timeline(data):
    cats = {}
    colormapping = {}
    for i, s in enumerate(data):
        if data[i][2] not in cats:
            cats[data[i][2]] = len(cats)+1
            colormapping[data[i][2]] = 'C' + str(len(cats)-1)
    print(cats)
    print(colormapping)
    
    verts = []
    colors = []
    for d in data:
        v =  [(d[0], cats[d[2]]-.2),
              (d[0], cats[d[2]]+.2),
              (d[1], cats[d[2]]+.2),
              (d[1], cats[d[2]]-.2),
              (d[0], cats[d[2]]-.2)]
        verts.append(v)
        colors.append(colormapping[d[2]])
    
    bars = PolyCollection(verts, facecolors=colors)
    
    fig, ax = plt.subplots(figsize=(20, 8))
    ax.xaxis.set_minor_locator(MultipleLocator(50))
    ax.xaxis.set_major_formatter(formatter)
    ax.add_collection(bars)
    ax.autoscale()
    
    ax.set_yticks(list(cats.values()))
    ax.set_yticklabels(list(cats))
    
    plt.grid(b=True,which='both')
    plt.show()

# %%
trans = data['results']['items']
keywords = []
for i, j in enumerate(trans):
    if (trans[i]['alternatives'][0]['content'] in search_words):
        keywords.append([trans[i]['start_time'], trans[i]['end_time'], trans[i]['alternatives'][0]['content']])
        #print(trans[i]['start_time'],trans[i]['start_time'],trans[i]['alternatives'][0]['content'])
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame(keywords)
# Out:
#           0        1         2
# 0    823.21    823.6     falta
# 1     933.5    933.7     falta
# 2    978.75   979.01     falta
# 3    988.85    989.1     falta
# 4   1002.17  1002.43     falta
# 5   1174.97  1178.16     falta
# 6   1397.39  1397.69     falta
# 7   1407.13  1407.69   tarjeta
# 8   1512.03  1512.34     falta
# 9    1512.4  1512.81   tarjeta
# 10  1512.81  1513.13  amarilla
# 11  1524.64  1524.98     falta
# 12  1533.77  1534.08   tarjeta
# 13  1534.08  1534.37  amarilla
# 14  1672.14  1672.56     falta
# 15  1715.73  1716.12     falta
# 16  1717.98  1718.63   tarjeta
# 17  1721.96  1722.76     falta
# 18  1723.46  1723.82  amarilla
# 19  1745.06  1745.41   tarjeta
# 20  1745.41  1745.71  amarilla
# 21  1823.18   1823.8     falta
# 22   1824.1   1824.5     falta
# 23  1839.94  1840.23     falta
# 24  1977.26  1977.63     falta
# 25   2091.3  2091.55       gol
# 26  2098.75  2099.02     falta
# 27  2183.56  2184.31     falta
# 28  2220.05   2220.5   disparo
# 29  2316.18  2316.61     falta
# 30  2326.17  2326.41     falta
# 31  2328.62  2329.05     falta
# 32  2332.76  2333.03     falta
# 33  2392.88  2393.27     falta
# 34  2489.83  2490.19   disparo
# 35  2685.38  2685.84   disparo
# 36  2712.24  2712.73  amarilla
# 37  2723.48   2724.0  amarilla
# 38   3182.5  3182.75   disparo
# 39  3195.01  3195.42   disparo
# 40  3215.09  3215.47     falta
# 41  3240.32  3240.53     falta
# 42  3242.82  3243.09     falta
# 43  3351.74   3352.8  amarilla
# 44  3392.15  3392.57     falta
# 45  3445.59  3446.36       gol
# 46  3853.79  3854.24   disparo
# 47  3924.87  3925.33     falta
# 48  4022.12  4022.47     falta
# 49  4249.03  4249.55       gol
# 50  4330.49  4330.66       gol
# 51  4355.67  4356.27   disparo
# 52  4394.48  4394.67       gol
# 53  4447.84  4448.09       gol
# 54   4571.7   4572.0   disparo
# 55  4758.87  4759.04       gol
# 56  4784.34  4792.81       gol
# 57  4846.82  4847.16     falta
# 58  4874.82  4875.02       gol
# 59  5079.52  5079.86   tarjeta
# 60  5079.86  5080.82  amarilla
# 61  5092.97  5093.21     falta
# 62  5098.78  5099.36     falta
# 63  5498.82  5499.13     falta
# 64  5686.53  5686.96     falta
# 65  5819.22  5820.08     falta
# 66  5998.61  5998.85     falta
# 67  6096.43  6096.75     falta
# 68   6142.4  6142.89   disparo
# 69  6155.71   6156.3   disparo
# 70  6218.28  6218.74  amarilla
# 71   6230.8  6231.14   tarjeta
# 72  6235.92  6236.29     falta
# 73  6301.69  6302.01  amarilla
# 74  6342.52  6342.96     falta
# 75  6386.92  6387.31   disparo
# 76   6432.0  6432.29     falta
# 77  6469.95  6470.33     falta

# %%
plot_timeline(keywords)
# Out:
# {'falta': 1, 'tarjeta': 2, 'amarilla': 3, 'gol': 4, 'disparo': 5}
# {'falta': 'C0', 'tarjeta': 'C1', 'amarilla': 'C2', 'gol': 'C3', 'disparo': 'C4'}

# %% [markdown]
# ## Mark relevant actions for highlights (based on activity detection and/or manual labeling)

# %%
action-dection-model = ''

### Batch inference media classification on action-detection-model


### Read manual labeling information for base media

# %% [markdown]
# ## Build clipping workflow based on the above
